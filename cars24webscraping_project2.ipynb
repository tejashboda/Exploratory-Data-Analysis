# %% [markdown]
# # WEB SCRAPING PROJECT - Cars24 Analysis (Part - 2)

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv('cars24.csv')

# %%
df
# Out:
#      Unnamed: 0  Year  Company       Car_Name             Model    Gear  \
# 0             0  2020   Maruti  Maruti Vitara               VXI  Manual
# 1             1  2021   Maruti   Maruti Dzire               VXI  Manual
# 2             2  2016  Hyundai  Hyundai Xcent             S 1.2  Manual
# 3             3  2021     Tata     Tata Tiago         XT PETROL  Manual
# 4             4  2018  Hyundai  Hyundai Elite          ASTA 1.2  Manual
# ..          ...   ...      ...            ...               ...     ...
# 416         416  2015   Maruti   Maruti Swift               VXI  Manual
# 417         417  2015   Maruti  Maruti Baleno  DELTA PETROL 1.2  Manual
# 418         418  2018     Tata     Tata NEXON         XT PETROL  Manual
# 419         419  2013   Maruti    Maruti Alto               LXI  Manual
# 420         420  2019   Datsun      Datsun Go                 T  Manual
#
#        Fuel  Ownership  Age    Kms    EMI  Down_Payment  Selling_Price  \
# ...

# %% [markdown]
# #### Q)The below chart tells about the company as in, which city and year and its car selling price are maximum or minimum and the number of cars available

# %%
df.groupby('Company')['Year','City','Selling_Price'].agg(['min','max','count'])
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\2840887948.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Company')['Year','City','Selling_Price'].agg(['min','max','count'])
#             Year                    City                Selling_Price  \
#              min   max count         min      max count           min
# Company
# Datsun      2016  2019     9   Bangaluru   Mumbai     9        238000
# Ford        2014  2020    16   Bangaluru   Nashik    16        455000
# Honda       2011  2022    41   Bangaluru   Nashik    41        240000
# Hyundai     2010  2022    72   Bangaluru   Nashik    72        185000
# Jeep        2017  2020     3     Chennai   Mumbai     3       1064000
# KIA         2020  2022     7   Bangaluru  Kolkata     7        783000
# MG          2020  2020     2  Coimbatore   Nashik     2       1511000
# ...

# %%
df['Company'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Tata', 'Volkswagen', 'Renault', 'Datsun',
#        'Nissan', 'Ford', 'Mahindra', 'Toyota', 'Honda', 'KIA', 'Skoda',
#        'Jeep', 'MG'], dtype=object)

# %%
len(df['Company'].unique())
# Out:
# 15

# %% [markdown]
# #### Q)The below chart tells about the company as in,in which city and which car of it  are maximum or minimum cars available

# %%
df.groupby('Company')['City','Car_Name'].agg(['min','max','count'])
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\2222571736.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Company')['City','Car_Name'].agg(['min','max','count'])
#                   City                        Car_Name
#                    min      max count              min               max count
# Company
# Datsun       Bangaluru   Mumbai     9        Datsun Go       Datsun Redi     9
# Ford         Bangaluru   Nashik    16    Ford Ecosport    Ford FREESTYLE    16
# Honda        Bangaluru   Nashik    41      Honda Amaze          Honda WR    41
# Hyundai      Bangaluru   Nashik    72     Hyundai AURA       Hyundai i20    72
# Jeep           Chennai   Mumbai     3     Jeep Compass      Jeep Compass     3
# KIA          Bangaluru  Kolkata     7       KIA SELTOS         KIA SONET     7
# MG          Coimbatore   Nashik     2        MG HECTOR         MG HECTOR     2
# ...

# %% [markdown]
# # Data Analysis and Data Visualization

# %% [markdown]
# - Visualization of the Entire Data using different Plots, Charts and Graphs.
# - Insights are provided by seeing the analysis.
# - Here the visualization is done the entire data and not only for the Problem Statement.
#
# #### Kind of Visualizations are split according to type of Analysis.
# - UNI - VARIATE ANALYSIS
# - BI - VARIATE ANALYSIS
# - MULTI - VARIATE ANALYSIS

# %% [markdown]
# #### These are the Plots, graphs and Charts used in visualy analysing the entire Data.
# - Bar plots
# - Count plots
# - Pie charts
# - Box plots
# - Histograms
# - Dist plots
# - KDE plots
# - Scatter plots
# - Pair plots
# - Heat maps

# %% [markdown]
# ## UNI - Variate Analysis

# %%
# Analysis for Company
#df['Company'] = df['Company'].str.strip()

# %%
sns.countplot(x=df['Company'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Insights
# - Maruti and Hyundai are the leading Car Companies where the used car are for sales
# - Nissan, Jeep and MG are the bottom 3 in terms of no of used cars for sale in the market

# %%
# count plot for car names columns.

plt.figure(figsize=(15,17))
sns.set_style('dark')
sns.countplot(y=df.Car_Name,data=cars,order=df.Car_Name.value_counts().index,color='violet') #ec = edge colour
plt.xlabel('Count for each Car Individually',fontsize=15)
plt.ylabel('Car Names',fontsize=15)
plt.title('Count Plot For Cars',fontsize=25,fontweight='bold',color='black')
plt.show()

# for all Car count is displayed.

# %% [markdown]
# ### INSIGHTS
# Maruti Swift, Maruti Alto , Maruti Wagon,and Hyundai Verna are the most number of used cars available for sale
#  we also observe that, there are about many cars which are for sale in equal magnitude ie. from Mahindra Bolero to Ford Freestyle

# %%
# car name and selling price
plt.figure(figsize=(15,20))
sns.set_style('dark')
selling_pricesort=df.sort_values('Selling_Price',ascending=False)
plt.barh(selling_pricesort.Car_Name,selling_pricesort.Selling_Price,color='#1560bd')
plt.ylabel('Individual Car Names',fontsize=15)
plt.xlabel('Range of Car Selling_Price',fontsize=15)
plt.title("BAR plot for Car_Name and Selling_Price",fontsize=25,fontweight='bold',color='black')
plt.show()

# %% [markdown]
# ### Insights
# - From the abpve two graphs we observe that as the selling price of the car increases, the number of cars in sale in that price decreases
# - the most no of cars availabel is Marutin swift but its selling price is the average selling price and the most costliest car is Toyota Fortuner but it is the less in number of cars available almost to bottom 7

# %%
# # Histogram for Campany.
sns.displot(df.Company)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### INSIGHTS
#
# most number of cars belongs to Maruti,Hyundai,Tata and Renault
# least number of cars belongs to Jeep and Nissan and MG

# %%
# Histogram for Selling_Pricing.

plt.figure(figsize=(20,12))
sns.set_style('dark')
plt.hist(df.Selling_Price,color='g',bins=30,ec='black')
plt.xlabel('Selling_Price',fontsize=18)
plt.ylabel('RANGES',fontsize=18)
plt.title('Histogram for Selling_Price',fontsize=25,fontweight='bold',color='black')
plt.show()

# for Pricing column range of distribution id displayed through Histogram.

# %% [markdown]
# ### Insights
# - from the above graph it is observed that most of the cars falls under the range of 2 lakhs-3 lakh
# - from 3-5 lakh there are less no of cars available
# - maximum number of cars are in the range 5-6.5 lakhs
# - very few are in the range 12-16 lakhs

# %%
# Histogram for EMI.

plt.figure(figsize=(20,12))
sns.set_style('dark')
plt.hist(df.EMI,color='b',bins=30,ec='black')
plt.xlabel('EMI',fontsize=18)
plt.ylabel('RANGES',fontsize=18)
plt.title('Histogram for EMI',fontsize=25,fontweight='bold',color='black')
plt.show()

# for Pricing column range of distribution id displayed through Histogram.

# %% [markdown]
# ### Insights
# - from the above graph it is observed that more no of cars are in the range of 4k to 12k of EMI and very less no of cars are there having EMI more than 15k

# %%
df['EMI'].value_counts()
# Out:
# 3754     5
# 4473     4
# 9400     4
# 9275     4
# 5787     3
#         ..
# 7670     1
# 8305     1
# 5498     1
# 7179     1
# 31688    1
# Name: EMI, Length: 324, dtype: int64

# %%
# Histogram for Duration_EMI

plt.figure(figsize=(20,12))
sns.set_style('dark')
plt.hist(df.Duration_EMI,color='b',bins=30,ec='black')
plt.xlabel('EMI',fontsize=18)
plt.ylabel('RANGES',fontsize=18)
plt.title('Histogram for Duration_EMI',fontsize=25,fontweight='bold',color='black')
plt.show()

# for Pricing column range of distribution id displayed through Histogram.

# %%
# Histogram for Down_Payment.

plt.figure(figsize=(20,12))
sns.set_style('dark')
plt.hist(df.Selling_Price,color='y',bins=30,ec='black')
plt.xlabel('Down_Payment',fontsize=18)
plt.ylabel('RANGES',fontsize=18)
plt.title('Histogram for Down_Payment',fontsize=25,fontweight='bold',color='black')
plt.show()

# for Pricing column range of distribution id displayed through Histogram.

# %% [markdown]
# ### Insights
# - from the above graph it is observed that most of the cars falls under the range of 2 lakhs-3 lakh
# - from 3-5 lakh there are less no of cars available
# - maximum number of cars are in the range 5-6.5 lakhs
# - very few are in the range 12-16 lakhs

# %%
# Histogram for Ownership.

plt.figure(figsize=(5,5))
sns.set_style('dark')
plt.hist(df.Ownership,color='g',bins=10,ec='black')
plt.xlabel('Ownership',fontsize=18)
plt.ylabel('RANGES',fontsize=18)
plt.title('Histogram for Ownership',fontsize=25,fontweight='bold',color='black')
plt.show()

# for Pricing column range of distribution id displayed through Histogram.

# %% [markdown]
# ### Insights
# - most no of cars for sale are 1st hand owner ie above 200+ cars and least are 4rd owners around 1

# %%
df['Ownership'].value_counts()
# Out:
# 1    273
# 2    124
# 3     23
# 4      1
# Name: Ownership, dtype: int64

# %%
# Pie plot for Company column.

plt.figure(figsize=(10,15))
sns.set_style('dark')
plt.pie(x=df.Company.value_counts().values,labels=df.Company.value_counts().index,shadow=True,autopct='%.1f%%',textprops={'fontsize':15})
plt.title('PIE Chart for Company',fontsize=30,fontweight='bold',color='black')
plt.legend(title='Different Companies',loc=1)
plt.show()

# percentage of each catagory

# %%
# distplot for Original_Price column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Selling_Price,color='blue',bins=20) # bind = no. of bars in plots
plt.xlabel('Selling_Price',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("Distibution of Selling_Price",fontsize=25,fontweight='bold',color='black')
plt.show()

# range of distribution id displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Insight
# - Maximum number of cars are having a selling price of 3-6 lakhs
# - As the selling price increases the density of cars also decreases
# - Average selling price of a car is 6 lakhs

# %%
df['Selling_Price'].describe()
# Out:
# count    4.210000e+02
# mean     6.045996e+05
# std      3.437352e+05
# min      1.300000e+05
# 25%      3.700000e+05
# 50%      5.670000e+05
# 75%      7.270000e+05
# max      2.700000e+06
# Name: Selling_Price, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Company       Car_Name      Model    Gear    Fuel  \
# 0           0  2020   Maruti  Maruti Vitara        VXI  Manual  Petrol
# 1           1  2021   Maruti   Maruti Dzire        VXI  Manual  Petrol
# 2           2  2016  Hyundai  Hyundai Xcent      S 1.2  Manual  Petrol
# 3           3  2021     Tata     Tata Tiago  XT PETROL  Manual  Petrol
# 4           4  2018  Hyundai  Hyundai Elite   ASTA 1.2  Manual  Petrol
#
#    Ownership  Age    Kms    EMI  Down_Payment  Selling_Price       City  \
# 0          1    3  90286  12349        162200         811000  Hyderabad
# 1          1    2  58886  10448        133600         668000  Hyderabad
# 2          1    7  21544   7945        101600         508000  Hyderabad
# 3          2    2  50878   9509        121600         608000  Hyderabad
# 4          1    5  50855  10213        130600         653000  Hyderabad
#
#    Duration_EMI
# 0     52.538667
# 1     51.148545
# 2     51.151668
# 3     51.151541
# 4     51.150494

# %%
# distplot for Duration_EMI column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Duration_EMI,color='blue',bins=20) # bind = no. of bars in plots
plt.xlabel('Duration_EMI',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("Distibution of Duration_EMI",fontsize=25,fontweight='bold',color='black')
plt.show()

# range of distribution id displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Box plot for Duration_EMI.

plt.figure(figsize=(22,5))
sns.set_style('dark')
sns.boxplot(x=df.Duration_EMI,color='#00bfff')
plt.xlabel('Duration_EMI',fontsize=20)
plt.title('BOX plot for EMI',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %% [markdown]
# ### INSIGHTS
# mixer of Hist plot and KDE plots.
# - Most of the Prices of the cars are having 50+ months duration for EMI
# - Very less to negligible betwenn 35 months to 45 months of installments

# %%
# distplot for Age column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Age,color='blue',bins=20) # bind = no. of bars in plots
plt.xlabel('Age',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("Distibution of Age",fontsize=25,fontweight='bold',color='black')
plt.show()
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### INSIGHTS
# mixer of Hist plot and KDE plots.
#
# - Most of the cars are lying between  the age of 4 to 5 years.
# - after 5 years as age increases the number of cars available also decreases.
# - the spread is increasing and then decreasing

# %%
# distplot for EMI column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.EMI,color='blue',bins=20) # bind = no. of bars in plots
plt.xlabel('EMI',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("Distibution of EMI",fontsize=25,fontweight='bold',color='black')
plt.show()
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### INSIGHTS
# mixer of Hist plot and KDE plots.
#
# - Most of the cars are having an EMI lying between  the age of 4k to just above 12.
# - Very less spread within the remaining ranges of EMI.
# - As the EMI increased the density of the car decreases
# - Mean EMI is around RS.9,565 with a standard deviation of Rs5,000

# %%
df['EMI'].describe()
# Out:
# count      421.000000
# mean      9565.102138
# std       5184.764606
# min       2033.000000
# 25%       6021.000000
# 50%       8931.000000
# 75%      11714.000000
# max      41114.000000
# Name: EMI, dtype: float64

# %%
# distplot for Kms column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Kms,color='blue',bins=20) # bind = no. of bars in plots
plt.xlabel('Kms',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("Distibution of Kms",fontsize=25,fontweight='bold',color='black')
plt.show()

# range of distribution id displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### INSIGHTS
# mixer of Hist plot and KDE plots.
#
# - Most of the cars have a Kms reading from 5,000 to 8,000kms.
# - Very less spread after 88000kms.
# - The mean distance reading is 64,000
# - The maximum is 5,33,416

# %%
df['Kms'].describe()
# Out:
# count       421.000000
# mean      64194.812352
# std       37154.662158
# min        3462.000000
# 25%       40462.000000
# 50%       61999.000000
# 75%       87667.000000
# max      533416.000000
# Name: Kms, dtype: float64

# %%
# KDE plot for Selling_Price column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Selling_Price,color='blue',bins=50,hist=False) # bind = no. of bars in plots
plt.xlabel('Selling_Price',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title(" KDE Distibution of Selling_Price",fontsize=25,fontweight='bold',color='black')
plt.show()

# Range of distibution is displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Insight
#  KDE - Kernel Density Estimation plot.
# - At first as the selling price increases the number of cars also increases later after a threshhold of 6 lakhs the number of cars decreases
# - Average selling price of a car is 6 lakhs

# %%
df['Selling_Price'].describe()
# Out:
# count    4.210000e+02
# mean     6.045996e+05
# std      3.437352e+05
# min      1.300000e+05
# 25%      3.700000e+05
# 50%      5.670000e+05
# 75%      7.270000e+05
# max      2.700000e+06
# Name: Selling_Price, dtype: float64

# %%
# KDE plot for EMI column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.EMI,color='blue',bins=25, hist=False) # bins = no. of bars in plots
plt.xlabel('EMI',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("KDE Distibution of EMI",fontsize=25,fontweight='bold',color='black')
plt.show()

# Range of distibution is displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### INSIGHTS
#  KDE plots.
#
# - Most of the cars are having an EMI lying between  the age of 4k to just above 12.
# - Very less spread within the remaining ranges of EMI.
# - As the EMI increased the density of the car decreases
# - Mean EMI is around RS.9,565 with a standard deviation of Rs5,000

# %%
df['EMI'].describe()
# Out:
# count      421.000000
# mean      9565.102138
# std       5184.764606
# min       2033.000000
# 25%       6021.000000
# 50%       8931.000000
# 75%      11714.000000
# max      41114.000000
# Name: EMI, dtype: float64

# %%
# KDE plot for Down_Payment

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Down_Payment,color='blue',bins=25, hist=False) # bins = no. of bars in plots
plt.xlabel('Dowm_Payment',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("KDE Distibution of Down_Payment",fontsize=25,fontweight='bold',color='black')
plt.show()

# Range of distibution is displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# KDE plot for Kms column.

plt.figure(figsize=(20,6))
sns.set_style('dark')
sns.distplot(df.Kms,color='blue',bins=25, hist=False) # bins = no. of bars in plots
plt.xlabel('Kms',fontsize=18)
plt.ylabel('DENSITY',fontsize=18)
plt.title("KDE Distibution of Kms",fontsize=25,fontweight='bold',color='black')
plt.show()

# Range of distibution is displayed.
# Out:
# C:\Users\INSPIRATION\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### INSIGHTS
#  KDE plots.
#
# - Most of the cars have a Kms reading from 5,000 to 8,000kms.
# - Very less spread after 88000kms.
# - The mean distance reading is 64,000
# - The maximum is 5,33,416

# %%
# Pie chart for Fuel Type column.

plt.figure(figsize=(10,15))
sns.set_style('dark')
plt.pie(x=df.Fuel.value_counts().values,labels=df.Fuel.value_counts().index,explode=(0.1,0.1,0.1),shadow=True,autopct='%.1f%%',textprops={'fontsize':15})
plt.title('PIE Chart for Fuel TYPE',fontsize=30,fontweight='bold',color='black')
plt.legend(title='Fuel TYPES',loc=1)
plt.show()

# percentage of each catagory.

# %% [markdown]
# ### Insights
# - There are more no of petrol cars at around 48% and CNG users automobiles are around 15% in the used cars availabel across 8 cities

# %%
sns.countplot(x=df['Fuel'])
plt.xticks()
plt.show()

# %% [markdown]
# #### How many and which type of fuel cars are there?

# %%
df['Fuel'].value_counts()
# Out:
# Petrol    205
# Diesel    150
# CNG        66
# Name: Fuel, dtype: int64

# %% [markdown]
# #### from each city which type of gear and which type of fuel cars are available and how many?

# %%
df.groupby('City')['Gear','Fuel'].value_counts()
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\1430601441.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Gear','Fuel'].value_counts()
# City        Gear       Fuel
# Bangaluru   Manual     Petrol    23
#                        Diesel    18
#                        CNG        4
#             Automatic  Diesel     2
#                        Petrol     2
# Chennai     Manual     Petrol    20
#                        Diesel    15
#                        CNG        6
#             Automatic  Petrol     5
#                        Diesel     5
# Coimbatore  Manual     Petrol    24
#                        Diesel    13
#             Automatic  Petrol     6
#                        Diesel     5
#             Manual     CNG        1
# Delhi       Manual     CNG       20
#                        Petrol    19
#                        Diesel    17
# ...

# %%
# Pie chart for Gear Type column.

plt.figure(figsize=(10,15))
sns.set_style('dark')
plt.pie(x=df.Gear.value_counts().values,labels=df.Gear.value_counts().index,explode=(0.1,0.1),shadow=True,autopct='%.1f%%',textprops={'fontsize':15})
plt.title('PIE Chart for Gear TYPE',fontsize=30,fontweight='bold',color='black')
plt.legend(title='Gear TYPES',loc=1)
plt.show()

# percentage of each catagory.

# %% [markdown]
# ### Insights
# - around 88% of the used cars are having manual gears
# - and 11% of Automatic gear

# %%
df['Gear'].value_counts()
# Out:
# Manual       372
# Automatic     49
# Name: Gear, dtype: int64

# %%
# percentage of ownerships
df['Ownership'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <AxesSubplot:ylabel='Ownership'>

# %%
df['Ownership'].value_counts()
# Out:
# 1    273
# 2    124
# 3     23
# 4      1
# Name: Ownership, dtype: int64

# %% [markdown]
# ### Insights
# - Most number of cars are 1st owners selling their cars
# - around 30% of the cars being sold are from 2 time owners
# - there is only one 4th time owner selling car

# %%
# Box plot for EMI.

plt.figure(figsize=(22,5))
sns.set_style('dark')
sns.boxplot(x=df.EMI,color='#00bfff')
plt.xlabel('EMI',fontsize=20)
plt.title('BOX plot for EMI',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %% [markdown]
# ### Insights
# - from the above boxplot there are outliers present
# - outliers are from EMI Rs.20,000

# %%
sns.violinplot(x='EMI', data=df)
plt.show()

# %% [markdown]
# ### Insights
# - Most of the cars are having an EMI lying between the inter quartile range.
# Very less spread after Rs.20,000/-
# As the EMI increased the density of the car decreases
# Mean EMI is around RS.9,565 with a standard deviation of Rs5,000

# %%
df['EMI'].describe()
# Out:
# count      421.000000
# mean      9565.102138
# std       5184.764606
# min       2033.000000
# 25%       6021.000000
# 50%       8931.000000
# 75%      11714.000000
# max      41114.000000
# Name: EMI, dtype: float64

# %%
# Box plot for Selling_Price

plt.figure(figsize=(22,5))
sns.set_style('dark')
sns.boxplot(x=df.Selling_Price,color='#00bfff')
plt.xlabel('Selling_Price',fontsize=20)
plt.title('BOX plot for Selling_Price',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %%
df['Selling_Price'].describe()
# Out:
# count    4.210000e+02
# mean     6.045996e+05
# std      3.437352e+05
# min      1.300000e+05
# 25%      3.700000e+05
# 50%      5.670000e+05
# 75%      7.270000e+05
# max      2.700000e+06
# Name: Selling_Price, dtype: float64

# %%
sns.violinplot(x='Selling_Price', data=df)
plt.show()

# %%
# Box plot for Down_Payment.

plt.figure(figsize=(22,5))
sns.set_style('dark')
sns.boxplot(x=df.Down_Payment,color='#00bfff')
plt.xlabel('Down_Payment',fontsize=20)
plt.title('BOX plot for Down_Payment',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %%
sns.violinplot(x='Down_Payment', data=df)
plt.show()

# %%
df['Down_Payment'].describe()
# Out:
# count       421.000000
# mean     120919.928741
# std       68747.037791
# min       26000.000000
# 25%       74000.000000
# 50%      113400.000000
# 75%      145400.000000
# max      540000.000000
# Name: Down_Payment, dtype: float64

# %%
# Box plot for Kms.

plt.figure(figsize=(22,5))
sns.set_style('dark')
sns.boxplot(x=cars.Kms,color='#00bfff')
plt.xlabel('Kms',fontsize=20)
plt.title('BOX plot for Kms',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %%
sns.violinplot(x='Kms', data=df)
plt.show()

# %% [markdown]
# ### Insights
# - From the above boxplot it clearly shows the absence of outliers and the violin chart also depicts the absence of spread as there are no outliers

# %%
df['Kms'].describe()
# Out:
# count       421.000000
# mean      64194.812352
# std       37154.662158
# min        3462.000000
# 25%       40462.000000
# 50%       61999.000000
# 75%       87667.000000
# max      533416.000000
# Name: Kms, dtype: float64

# %% [markdown]
# #### Each car name has how many cars?

# %%
df['Car_Name'].value_counts()
# Out:
# Maruti Swift        34
# Maruti Alto         31
# Maruti Wagon        18
# Hyundai Verna       17
# Honda Amaze         17
#                     ..
# Volkswagen Ameo      1
# Honda Civic          1
# Mahindra SCORPIO     1
# Tata Harrier         1
# Ford FREESTYLE       1
# Name: Car_Name, Length: 70, dtype: int64

# %% [markdown]
# ## Bi- Variate & Multi-Variate Analysis

# %%
#Column Gear with Selling Price
sns.barplot(x=df['Gear'], y = df['Selling_Price'])
plt.xticks()
plt.show()

# %%
df.groupby('Gear')['Selling_Price'].describe()
# Out:
#            count           mean            std       min       25%       50%  \
# Gear
# Automatic   49.0  841281.632653  385913.368772  394000.0  598000.0  706000.0
# Manual     372.0  573423.790323  325756.727488  130000.0  350500.0  534500.0
#
#                 75%        max
# Gear
# Automatic  970000.0  2081000.0
# Manual     694250.0  2700000.0

# %% [markdown]
# ### Insights
# - from the above graph it is observed that the maximum selling price of manual cars is 27 lakhs which is an outlier
#   and automatic is 20 lakhs
# - the mean of selling price for automatice is 8 lakhs and for manual cars is 5.7 lakhs
# - Automatic price range (4-20 lakhs)
# - Manual price range (1.3-27 lakhs)

# %% [markdown]
# ##### Q) which company has how many Manual or Automatic cars?

# %%
df.groupby('Company')['Gear'].value_counts()
# Out:
# Company     Gear
# Datsun      Manual         9
# Ford        Manual        16
# Honda       Manual        35
#             Automatic      6
# Hyundai     Manual        62
#             Automatic     10
# Jeep        Manual         3
# KIA         Manual         4
#             Automatic      3
# MG          Manual         2
# Mahindra    Manual        23
#             Automatic      2
# Maruti      Manual       154
#             Automatic     12
# Nissan      Automatic      2
#             Manual         1
# Renault     Manual        13
#             Automatic      3
# Skoda       Automatic      5
#             Manual         5
# Tata        Manual        27
#             Automatic      3
# Toyota      Manual         8
#             Automatic      2
# Volkswagen  Manual        10
#             Automatic      1
# Name: Gear, dtype: int64

# %% [markdown]
# #### Q) In each city how many and what type of gear cars are available?

# %%
df.groupby('City')['Gear'].value_counts()
# Out:
# City        Gear
# Bangaluru   Manual       45
#             Automatic     4
# Chennai     Manual       41
#             Automatic    10
# Coimbatore  Manual       38
#             Automatic    11
# Delhi       Manual       56
#             Automatic     4
# Hyderabad   Manual       43
#             Automatic     6
# Kolkata     Manual       53
#             Automatic     2
# Mumbai      Manual       54
#             Automatic     6
# Nashik      Manual       42
#             Automatic     6
# Name: Gear, dtype: int64

# %%
# fuel and compay horizontal bar plot
df.groupby('Company')['Fuel'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Company,Fuel'>

# %% [markdown]
# ### Insights
# - It is observed that only Datson,Hyundai,Honda,Maruti,Renault,Tata,Toyota are offering cars using CNG as fuel

# %% [markdown]
# ##### Q) From which company , which time owners are selling their cars?

# %%
# line of ownership in relation to company
df.groupby('Ownership')['Company'].value_counts()
# Out:
# Ownership  Company
# 1          Maruti        114
#            Hyundai        41
#            Tata           23
#            Honda          16
#            Mahindra       16
#            Ford           13
#            Renault        11
#            Skoda          10
#            Datsun          8
#            KIA             7
#            Toyota          5
#            Volkswagen      3
#            Jeep            2
#            MG              2
#            Nissan          2
# 2          Maruti         37
#            Hyundai        28
#            Honda          24
#            Mahindra        8
#            Volkswagen      7
#            Tata            6
#            Renault         4
#            Toyota          4
#            Ford            3
#            Datsun          1
#            Jeep            1
#            Nissan          1
# 3          Maruti         15
#            Hyundai         3
#            Honda           1
#            Mahindra        1
# ...

# %% [markdown]
# ##### Q)From which city , which time owners are selling the most?

# %%
df.groupby('City')['Ownership'].value_counts()#Delhi
# Out:
# City        Ownership
# Bangaluru   1            26
#             2            21
#             3             2
# Chennai     1            35
#             2            11
#             3             5
# Coimbatore  1            35
#             2            14
# Delhi       1            47
#             2             9
#             3             4
# Hyderabad   1            32
#             2            16
#             3             1
# Kolkata     1            43
#             2            11
#             3             1
# Mumbai      1            27
#             2            24
#             3             8
#             4             1
# Nashik      1            28
#             2            18
#             3             2
# Name: Ownership, dtype: int64

# %% [markdown]
# ##### Q)Describe ownership vs Kms in terms of statistics?

# %%
df.groupby('Ownership')['Kms'].describe()
# Out:
#            count          mean           std      min      25%      50%  \
# Ownership
# 1          273.0  59386.263736  41357.328934   3462.0  34966.0  53039.0
# 2          124.0  72063.814516  25766.551350  25429.0  50284.0  70441.0
# 3           23.0  78685.695652  25284.694730  22293.0  72128.0  85307.0
# 4            1.0  67882.000000           NaN  67882.0  67882.0  67882.0
#
#                75%       max
# Ownership
# 1          81711.0  533416.0
# 2          94442.0  121990.0
# 3          92557.5  117255.0
# 4          67882.0   67882.0

# %%
df.groupby('Ownership')['Kms'].agg(['min','max','mean','count']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Ownership'>

# %% [markdown]
# #### Q)from which city which owners belong?

# %%
df.groupby('Ownership')['City'].value_counts()#.plot(kind='bar')
# Out:
# Ownership  City
# 1          Delhi         47
#            Kolkata       43
#            Chennai       35
#            Coimbatore    35
#            Hyderabad     32
#            Nashik        28
#            Mumbai        27
#            Bangaluru     26
# 2          Mumbai        24
#            Bangaluru     21
#            Nashik        18
#            Hyderabad     16
#            Coimbatore    14
#            Chennai       11
#            Kolkata       11
#            Delhi          9
# 3          Mumbai         8
#            Chennai        5
#            Delhi          4
#            Bangaluru      2
#            Nashik         2
#            Hyderabad      1
#            Kolkata        1
# 4          Mumbai         1
# Name: City, dtype: int64

# %%
df.groupby('Ownership')['City'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Ownership,City'>

# %%
df.describe()
# Out:
#        Unnamed: 0         Year   Ownership         Age            Kms  \
# count  421.000000   421.000000  421.000000  421.000000     421.000000
# mean   210.000000  2016.833729    1.410926    6.166271   64194.812352
# std    121.676484     3.004109    0.605353    3.004109   37154.662158
# min      0.000000  2010.000000    1.000000    0.000000    3462.000000
# 25%    105.000000  2015.000000    1.000000    4.000000   40462.000000
# 50%    210.000000  2017.000000    1.000000    6.000000   61999.000000
# 75%    315.000000  2019.000000    2.000000    8.000000   87667.000000
# max    420.000000  2023.000000    4.000000   13.000000  533416.000000
#
#                 EMI   Down_Payment  Selling_Price  Duration_EMI
# count    421.000000     421.000000   4.210000e+02    421.000000
# mean    9565.102138  120919.928741   6.045996e+05     50.368368
# std     5184.764606   68747.037791   3.437352e+05      4.432602
# min     2033.000000   26000.000000   1.300000e+05     11.254858
# ...

# %%
# Age vs Ownership
sns.displot(x='Age', data=df, kde=True)
plt.title("Age of Ownership")
plt.show()

# %%
df.groupby('Ownership')['Age'].describe()
# Out:
#            count       mean       std   min   25%   50%   75%   max
# Ownership
# 1          273.0   5.307692  2.819414   0.0   3.0   5.0   7.0  13.0
# 2          124.0   7.637097  2.765451   2.0   5.0   7.5  10.0  13.0
# 3           23.0   8.260870  2.157806   4.0   7.0   8.0   9.5  12.0
# 4            1.0  10.000000       NaN  10.0  10.0  10.0  10.0  10.0

# %% [markdown]
# #### Insights
# - 1st time owners are more and the mean age of the cars is 5 years
# - 2nd and 3rd time owners the mean age of the cars are 7 and 8 years
# - As the Age increases the number of cars for sale decrease
# - Maximum number of cars lie between the age group 4 to 6 Years

# %%
# EMI vs Ownership
sns.histplot(x='EMI', data=df, hue='Ownership')
plt.title("Histogram  plot EMI vs Ownership")
plt.show()

# %%
df.groupby('Ownership')['EMI'].describe()
# Out:
#            count          mean          std      min       25%      50%  \
# Ownership
# 1          273.0  10209.780220  5484.131380   2033.0   6866.00   9447.0
# 2          124.0   8677.830645  4551.263535   2502.0   5480.25   7956.5
# 3           23.0   6545.478261  2422.042205   3660.0   4840.50   6088.0
# 4            1.0  13041.000000          NaN  13041.0  13041.00  13041.0
#
#                 75%      max
# Ownership
# 1          12074.00  41114.0
# 2          10451.75  32739.0
# 3           7800.50  12465.0
# 4          13041.00  13041.0

# %%
sns.set_style('dark')
sns.pairplot(df.loc[:,'EMI':])
plt.show()

# %%
# company vs selling price
sns.catplot(x='Company', y='Selling_Price', data=df, kind='box')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Insights
# - Hyundai,Tata,Mahindra,Honda have outliers meaning thier selling price of cars is too how and skoda has negative outlier meaning its selling price of its car is low comparatively

# %%
# car_name vsKms
plt.figure(figsize=(15,20))
sns.set_style('dark')
sns.boxplot(x='Kms',y='Car_Name',data=df,order=df.Car_Name.value_counts().index,color='#b94e48')
plt.ylabel('Individual Car_Names',fontsize=15)
plt.xlabel('Range of Kms Travelled',fontsize=15)
plt.title("BOX plot for Car_Name and Kms Travelled ",fontsize=25,fontweight='bold',color='black')
plt.show()

# %%
df.groupby('Car_Name')['Kms'].agg(['min','max','mean','count'])
# Out:
#                     min     max           mean  count
# Car_Name
# Datsun Go         10216   72762   31382.625000      8
# Datsun Redi       67155   67155   67155.000000      1
# Ford Ecosport     16817  122112   69805.866667     15
# Ford FREESTYLE    40434   40434   40434.000000      1
# Honda Amaze       26999  106457   59498.000000     17
# ...                 ...     ...            ...    ...
# Toyota Innova     53294   93765   74312.750000      4
# Volkswagen Ameo   42048   42048   42048.000000      1
# Volkswagen Cross  93510   93510   93510.000000      1
# Volkswagen Polo   94634  111214  101771.200000      5
# Volkswagen Vento  52858  110430   78775.750000      4
#
# [70 rows x 4 columns]

# %%
# car name and age
plt.figure(figsize=(15,20))
sns.set_style('dark')
car_age=df.sort_values('Age',ascending=False)
plt.barh(car_age.Car_Name,car_age.Age,color='#2f4f4f')
plt.ylabel('Individual Car Names',fontsize=15)
plt.xlabel('Age of Car',fontsize=15)
plt.title("BAR plot for Car_Name and Age",fontsize=25,fontweight='bold',color='black')
plt.show()

# %%
# Company vs Age
plt.figure(figsize=(15,20))
sns.set_style('dark')
plt.barh(df.Company,df.Age,color='#9932cc')
plt.ylabel('Individual Car Company',fontsize=15)
plt.xlabel('Age of Car',fontsize=15)
plt.title("BAR plot for Company and Age",fontsize=15,fontweight='bold',color='black')
plt.show()

# %%
# car name vs emi duration
plt.figure(figsize=(15,20))
sns.set_style('dark')
car_duration=df.sort_values('Duration_EMI',ascending=False)
plt.barh(car_duration.Car_Name,car_duration.Duration_EMI,color='#2f4f4f')
plt.ylabel('Individual Car Names',fontsize=15)
plt.xlabel('EMI_Duration of Car',fontsize=15)
plt.title("BAR plot for Car_Name and EMI_Duration",fontsize=25,fontweight='bold',color='black')
plt.show()

# %%
# Finding the correlationship of all the numerical columns in the data frame
df.corr()
# Out:
#                Unnamed: 0      Year  Ownership       Age       Kms       EMI  \
# Unnamed: 0       1.000000  0.067495  -0.089152 -0.067495 -0.122208 -0.085670
# Year             0.067495  1.000000  -0.379994 -1.000000 -0.331039  0.520947
# Ownership       -0.089152 -0.379994   1.000000  0.379994  0.175028 -0.180924
# Age             -0.067495 -1.000000   0.379994  1.000000  0.331039 -0.520947
# Kms             -0.122208 -0.331039   0.175028  0.331039  1.000000 -0.062119
# EMI             -0.085670  0.520947  -0.180924 -0.520947 -0.062119  1.000000
# Down_Payment    -0.077525  0.567488  -0.203434 -0.567488 -0.086640  0.980952
# Selling_Price   -0.077525  0.567488  -0.203434 -0.567488 -0.086640  0.980952
# Duration_EMI     0.044630  0.373822  -0.175942 -0.373822 -0.140106  0.082920
#
#                Down_Payment  Selling_Price  Duration_EMI
# Unnamed: 0        -0.077525      -0.077525      0.044630
# Year               0.567488       0.567488      0.373822
# ...

# %%
# plotting heatmap to measure the strength of the relationship
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),linewidth=10,annot=True)
plt.show()

# %% [markdown]
#  ## Objective of the Project
#  To Help the client make a decision based on his requirement
#  Client requirement is to buy a best used car within a budget of 7 lakhs and make the best use of his money
#
#
#  There are 2 cases to help meet the client requirement
#  case 1:
#  In order the buy a best used car the car needs to meet the following criteria namely:
#  1.Age of the car should be less as it ensures the latest engine and increasing the life of the car
#  2.The car should be in the range 0 to 7 lakhs in terms of one time settlement
#  3.The no of kilometers travelled shall be less
#  4.less no of ownership (less than 2)

# %% [markdown]
# ### Case 1:

# %%
#now the criteria of a good car is very vague in terms of Kms travelled and age and line of ownership therefore its better \
#to eliminate the outliers in the data set and check for the cars by applying the above stated conditions

# %%
# identifying the outliers for Selling Price travelled by plotting a simple box plot 
# Box plot for Kms.

plt.figure(figsize=(15,5))
sns.set_style('dark')
sns.boxplot(x=df.Selling_Price,color='blue')
plt.xlabel('Selling Price',fontsize=20)
plt.title('BOX plot for Selling Price',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection.

# %%
#As it is evident from the above graph that there are more than one  outliers present there for to make the data set uniform 
# removing the outliers

# %%
# to find out the inter quartile range of the numerical columns.

q3=df.Selling_Price.quantile(0.75)
q1=df.Selling_Price.quantile(0.25)
iqr=q3-q1
upperbound=q3+1.5*iqr
lowerbound=q1-1.5*iqr


print(q3,'\n',q1,'\n',iqr,'\n',upperbound,'\n',lowerbound)

# printing all the elements of IQR.
# Out:
# 727000.0
#  370000.0
#  357000.0
#  1262500.0
#  -165500.0

# %%
# Detecting the outliers and saving into a variable.

outliers=df[df.Selling_Price>upperbound]
print(outliers.Selling_Price)

# printing the outliers.
# Out:
# 24     2150000
# 27     1497000
# 38     1522000
# 70     1288000
# 77     1973000
# 131    1451000
# 132    1459000
# 134    1846000
# 137    2350000
# 175    1788000
# 188    1521000
# 241    2700000
# 242    1821000
# 245    1318000
# 246    1300000
# 348    1511000
# 389    1816000
# 393    1269000
# 394    1449000
# 409    2081000
# Name: Selling_Price, dtype: int64

# %%
# getting data without outliers and saving into a variable.

df2=df[df.Selling_Price<upperbound]
df2.Selling_Price.describe()

# now getting all statistical values on that column.
# Out:
# count    4.010000e+02
# mean     5.496919e+05
# std      2.307034e+05
# min      1.300000e+05
# 25%      3.630000e+05
# 50%      5.470000e+05
# 75%      6.900000e+05
# max      1.198000e+06
# Name: Selling_Price, dtype: float64

# %%
# to see the missing values.

df2.isnull().sum()

# missing values in each column.
# Out:
# Unnamed: 0       0
# Year             0
# Company          0
# Car_Name         0
# Model            0
# Gear             0
# Fuel             0
# Ownership        0
# Age              0
# Kms              0
# EMI              0
# Down_Payment     0
# Selling_Price    0
# City             0
# Duration_EMI     0
# dtype: int64

# %%
df2.head()
# Out:
#    Unnamed: 0  Year  Company       Car_Name      Model    Gear    Fuel  \
# 0           0  2020   Maruti  Maruti Vitara        VXI  Manual  Petrol
# 1           1  2021   Maruti   Maruti Dzire        VXI  Manual  Petrol
# 2           2  2016  Hyundai  Hyundai Xcent      S 1.2  Manual  Petrol
# 3           3  2021     Tata     Tata Tiago  XT PETROL  Manual  Petrol
# 4           4  2018  Hyundai  Hyundai Elite   ASTA 1.2  Manual  Petrol
#
#    Ownership  Age    Kms    EMI  Down_Payment  Selling_Price       City  \
# 0          1    3  90286  12349        162200         811000  Hyderabad
# 1          1    2  58886  10448        133600         668000  Hyderabad
# 2          1    7  21544   7945        101600         508000  Hyderabad
# 3          2    2  50878   9509        121600         608000  Hyderabad
# 4          1    5  50855  10213        130600         653000  Hyderabad
#
#    Duration_EMI
# 0     52.538667
# 1     51.148545
# 2     51.151668
# 3     51.151541
# 4     51.150494

# %%
# identifying the outliers for Age by plotting a simple box plot 
# Box plot for Age.

plt.figure(figsize=(10,5))
sns.set_style('dark')
sns.boxplot(x=df2.Age,color='blue')
plt.xlabel('Age',fontsize=20)
plt.title('BOX plot for Age',fontsize=30,fontweight='bold',color='black')
plt.show()

# Outliers detection. here also no outliers detected

# %%
case1=df2[(df2['Ownership']<4) & (df2['Selling_Price']<=700000) & (df2['Gear']=='Automatic')&(df2['Age']<=6)]

# %%
# car frequency
plt.figure(figsize=(20,8))
sns.set_style('dark')
sns.countplot(x=case1.Company,order=case1.Company.value_counts().index,color='#0d98ba',ec='black')
plt.xlabel("Individual Company",fontsize=20)
plt.ylabel("count of Nos",fontsize=20)
plt.title("Count Plot For Company cars's",fontsize=25,fontweight='bold',color='black')
plt.show()

# %%
case1['Company'].value_counts()
# Out:
# Maruti     7
# Renault    3
# Hyundai    2
# Skoda      1
# Nissan     1
# Honda      1
# Name: Company, dtype: int64

# %%
# car name and selling price
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_selling=cars.sort_values('Selling_Price',ascending=False)
plt.barh(case1.Car_Name,case1.Selling_Price,color='#0095b6')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('Selling_Price of Car',fontsize=10)
plt.title("BAR plot for Car_Name and Selling_Price",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
# car name vs Kms plot
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_kms=cars.sort_values('Kms',ascending=False)
plt.barh(case1.Car_Name,case1.Kms,color='#1dacd6')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('Kms of Car',fontsize=10)
plt.title("BAR plot for Car_Name and Kms",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Down_Payment','City'].value_counts()
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\2702976276.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Down_Payment','City'].value_counts()
# Company  Car_Name        Age  Kms     Gear       Selling_Price  EMI    Down_Payment  City
# Honda    Honda Jazz      6    35266   Automatic  539000         8430   107800        Coimbatore    1
# Hyundai  Hyundai Grand   5    24914   Automatic  636000         9947   127200        Hyderabad     1
#          Hyundai NEW     5    52585   Automatic  531000         8305   106200        Mumbai        1
# Maruti   Maruti Baleno   6    44254   Automatic  593000         9275   118600        Coimbatore    1
#                               65575   Automatic  648000         10135  129600        Coimbatore    1
# ...

# %% [markdown]
# ##### From the above chart we can say that Reanult Kwid is the 1st best car and Maruti S is the 2nd best car in terms of health of the engine and the distance travelled by the car

# %%
# # Histogram for Campany.
sns.displot(case1.Car_Name)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style('dark')
sns.pairplot(case1.loc[:,'EMI':])
plt.show()

# %% [markdown]
# ##### In a single time payment Renault kwid from Bangaluru =Rs.591000 and Maruti S from Nashik =Rs.543000 are the best budget cars to buy

# %% [markdown]
# ### Case 2
#
# where the client utilizes a portion of his budget to buy a personal car and the rest uses to invest in a car for starting a cab services
# The only possibility here is to buy the car in terms of EMI due to budget constraints therefor find the maximum Dowm payment value

# %% [markdown]
# keeping in mind to have a long lasting business and good returns its best to invest in a good car than taking less EMI as a factor to choose a car for higher returns. we will take case1 as the criteria and use its data set to buy cars

# %%
case1.describe()
# Out:
#        Unnamed: 0        Year  Ownership       Age            Kms  \
# count   15.000000    15.00000  15.000000  15.00000      15.000000
# mean   262.133333  2018.00000   1.333333   5.00000   50552.866667
# std    137.095309     1.36277   0.617213   1.36277   33698.201028
# min     18.000000  2017.00000   1.000000   2.00000    5567.000000
# 25%    134.500000  2017.00000   1.000000   5.00000   24423.000000
# 50%    337.000000  2018.00000   1.000000   5.00000   35266.000000
# 75%    378.500000  2018.00000   1.500000   6.00000   77113.000000
# max    388.000000  2021.00000   3.000000   6.00000  106929.000000
#
#                 EMI   Down_Payment  Selling_Price  Duration_EMI
# count     15.000000      15.000000      15.000000     15.000000
# mean    9331.466667  118146.666667  590733.333333     50.737062
# std     1219.081028   14008.256069   70041.280345      1.599823
# min     6475.000000   82800.000000  414000.000000     44.954048
# ...

# %% [markdown]
# As from case 1 it is obvious that the best car was Renault kwid and Maruti S within the budget

# %%
case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Duration_EMI','Down_Payment','City'].value_counts()
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\604370762.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Duration_EMI','Down_Payment','City'].value_counts()
# Company  Car_Name        Age  Kms     Gear       Selling_Price  EMI    Duration_EMI  Down_Payment  City
# Honda    Honda Jazz      6    35266   Automatic  539000         8430   51.150652     107800        Coimbatore    1
# Hyundai  Hyundai Grand   5    24914   Automatic  636000         9947   51.151101     127200        Hyderabad     1
#          Hyundai NEW     5    52585   Automatic  531000         8305   51.149910     106200        Mumbai        1
# Maruti   Maruti Baleno   6    44254   Automatic  593000         9275   51.148248     118600        Coimbatore    1
# ...

# %%
case1
# Out:
#      Unnamed: 0  Year  Company        Car_Name                     Model  \
# 18           18  2018  Hyundai   Hyundai Grand  SPORTZ AT 1.2 KAPPA VTVT
# 62           62  2021  Renault    Renault Kwid           RXT 1.0 AMT (O)
# 108         108  2018  Renault    Renault Kwid           RXT 1.0 AMT (O)
# 110         110  2018   Maruti    Maruti IGNIS              ZETA 1.2 AMT
# 159         159  2018  Hyundai     Hyundai NEW                SPORTZ AMT
# 186         186  2017    Skoda     Skoda Rapid          STYLE 1.5 TDI AT
# 332         332  2019   Maruti        Maruti S              VXI PLUS AMT
# 337         337  2017   Maruti    Maruti Dzire                   VXI AMT
# 350         350  2018   Maruti    Maruti Dzire                   ZDI AMT
# 352         352  2017   Nissan  Nissan Terrano          XV D PREMIUM AMT
# 378         378  2017   Maruti   Maruti Baleno       ZETA CVT PETROL 1.2
# 379         379  2017   Maruti   Maruti Baleno       ZETA CVT PETROL 1.2
# ...

# %%
plt.figure(figsize=(20,8))
sns.set_style('dark')
sns.countplot(x=case1.Company,order=case1.Company.value_counts().index,color='#8b008b',ec='black')
plt.xlabel("Individual Company",fontsize=20)
plt.ylabel("count of Nos",fontsize=20)
plt.title("Count Plot For Company cars's",fontsize=25,fontweight='bold',color='black')
plt.show()

# %%
case1['Company'].value_counts()
# Out:
# Maruti     7
# Renault    3
# Hyundai    2
# Skoda      1
# Nissan     1
# Honda      1
# Name: Company, dtype: int64

# %%
# car name vs down payment
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_down=case1.sort_values('Down_Payment',ascending=False)
plt.barh(case1.Car_Name,case1.Down_Payment,color='#08e8de')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('Down_Payment of Car',fontsize=10)
plt.title("BAR plot for Car_Name and Down_Payment",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
# car name vs age
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_age=case1.sort_values('Age',ascending=False)
plt.barh(case1.Car_Name,case1.Age,color='#c19a6b')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('Age of Car',fontsize=10)
plt.title("BAR plot for Car_Name and Age",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
# car name vs emi
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_emi=case1.sort_values('EMI',ascending=False)
plt.barh(case1.Car_Name,case1.EMI,color='#00bfff')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('EMI of Car',fontsize=10)
plt.title("BAR plot for Car_Name and EMI",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.set_style('dark')
car_kms=case1.sort_values('Kms',ascending=False)
plt.barh(case1.Car_Name,case1.Kms,color='#00cc99')
plt.ylabel('Individual Car Names',fontsize=10)
plt.xlabel('Kms of Car',fontsize=10)
plt.title("BAR plot for Car_Name and Kms",fontsize=10,fontweight='bold',color='black')
plt.show()

# %%
case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Duration_EMI','Down_Payment','City'].value_counts()
# Out:
# C:\Users\INSPIRATION\AppData\Local\Temp\ipykernel_2272\604370762.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   case1.groupby('Company')['Car_Name','Age','Kms','Gear','Selling_Price','EMI','Duration_EMI','Down_Payment','City'].value_counts()
# Company  Car_Name        Age  Kms     Gear       Selling_Price  EMI    Duration_EMI  Down_Payment  City
# Honda    Honda Jazz      6    35266   Automatic  539000         8430   51.150652     107800        Coimbatore    1
# Hyundai  Hyundai Grand   5    24914   Automatic  636000         9947   51.151101     127200        Hyderabad     1
#          Hyundai NEW     5    52585   Automatic  531000         8305   51.149910     106200        Mumbai        1
# Maruti   Maruti Baleno   6    44254   Automatic  593000         9275   51.148248     118600        Coimbatore    1
# ...

# %% [markdown]
# ##### Renault Kwid downpayment=1,18,200/- EMI= 9243 Duration=51
# ##### Hyundai Grand downpayement=1,27,200/- EMI=9,947/-
# ##### Total down payment cost = 2,45,200/-
# ##### Net amount left after paying down payment =7,00,000-2,45,200=4,54,800/-
# ##### the average cost to hire a driver is Rs 20,000
# ##### maintenance cost and Fuel cost is Rs=5,000
# ##### the average income in cab industry is 45,000
# ##### net income is 45,000-25,000=20,000
# ##### Total EMI is Renault Kwid and Hyundai Grand is (9,243+9,947) is Rs19190/-
# ##### Total EMI per year=19190*12=2,30,280/-
# ##### In a year net income=2,40,000-2,30,280=9,720/-
# ##### EMI duration for Nissan is 4year
# ##### EMI duration for Hyundai Aura is 4

# %% [markdown]
# #### Renault Kwid and Hyundai Grand  are within the budget of 7,00,000/-  to buy where in one can be
# #### used for  personal use and 2nd can be used for the business purpose.
# #### Income from one car can be used to pay for both the cars as the evidant from the above calculation after 4 yrs both the cars
#
# #### will be owned by the client, and generating the revenue of 2,40,000/- per annum.
